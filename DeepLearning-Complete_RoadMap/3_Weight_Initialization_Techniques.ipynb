# %% [markdown]
# #### T12 - Weight Initialization Techniques
#
#
# Key points to note while Initializing Weights
#
# 1. Weights should be small
# 2. Weights should not be same
# 3. Weights should have good variance - Weights should be different , becuase each and every neuron is responsible for learning something from input features
#
# Terminology to remember , before learning weight initialization techniques
#
# Consider one hidden neuron which contains 4 inputs (fan_in) and one output (fan_out)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Weight Initialization Techniques
#
# 1. Uniform Distribution   ------- It works really well with Sigmoid Activation Function
# 2. Xavier/Gorat Distribution  --- It works really well with Sigmoid Activation Function
# 3. HE init ---------------------- It works really well with RELU Activation function

# %% [markdown]
# #### 1. Uniform Distribution -- Works well with Sigmoid Activation Function
#
# In these weights will be taken from Uniform Distribution with some a(lower end) and b(upper end) value
#
# Formula
#
# ![image.png](attachment:image.png)

# %% [markdown]
# If there are 3 input features then weights Between Input and Hidden layeer 1 will be initialized from uniform distribution between (-1/Root(3) , 1/Root(3))

# %% [markdown]
# #### 2. Xavier/Gorat Distribution -- Works well with Sigmoid Activation function
#
# It is divided into 2 types :
# 1. Xavier/Gorat Normal
# 2. Xavier/Gorat Uniform
#
# ##### Xavier/Gorat Normal
#
# Weights are initialized with Normal Distribution of (Mean 0 , Some Std Deviation). Sigma/Std is given by below formula w.r.t fan_in
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Xavier Uniform
#
# Weights are initialized from Uniform distribution Between (See Formula)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. HE init
#
# He init is divided into 2 types :
# 1. HE Normal
# 2. HE Uniform
#
# #### HE Normal
#
# Weights are initialized with Normal Distribution between a and b range given below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### HE Uniform
#
# Weights are initialized from Uniform Distribution between a and b range given below
#
# ![image.png](attachment:image.png)
